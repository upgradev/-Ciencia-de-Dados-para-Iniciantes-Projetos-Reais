# %%
import pandas as pd

# %%
df = pd.read_csv('house.csv')

# %%
# df.groupby(['SellerG'])[['Rooms', 'Price', 'Postcode', 'Propertycount', 'Distance']].mean() #tirar uma media de cada vendedor
# df.groupby(['SellerG'])[['Rooms', 'Price', 'Postcode', 'Propertycount', 'Distance']].sum().sort_values('Price', ascending=False).head(10) # os melhores vendedores 
# df.groupby(['SellerG'])[['Rooms', 'Price', 'Postcode', 'Propertycount', 'Distance']].sum().sort_values('Rooms', ascending=False).head(10) # os melhores vendedores por quartos
df.groupby(['SellerG'])[['Rooms', 'Price', 'Postcode', 'Propertycount', 'Distance']].count()
# Out:
#               Rooms  Price  Postcode  Propertycount  Distance
# SellerG
# @Realty          27     21        27             27        27
# A                 9      6         9              9         9
# AIME              1      1         1              1         1
# ASL              10     10        10             10        10
# Abercromby's     68     42        68             68        68
# ...             ...    ...       ...            ...       ...
# iOne              1      1         1              1         1
# iProperty         1      1         1              1         1
# iSell           127     99       127            127       127
# iTRAK            75     70        75             75        75
# voglwalpole       4      2         4              4         4
#
# [476 rows x 5 columns]
